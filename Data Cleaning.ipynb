# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("Datasets/fact_bookings.csv")
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
#Find out how many negative nos are there
df_bookings[df_bookings.no_guests<=0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %%
'''We can handle negative values by ignoring them, since they are few in number. After filtering them out, 
   we will store the cleaned data back into the same DataFrame'''
df_bookings = df_bookings[df_bookings.no_guests>0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
#Find the min & max of revenue generated
print(f"Minimum_Bookings:- {df_bookings.revenue_generated.min()}"),
print(f"Maximum_Bookings:- {df_bookings.revenue_generated.max()}"),
print(f"Average_Bookings:- {df_bookings.revenue_generated.mean()}")
#These nos are incorrect beacuse in bookings dataframes it refers to single booking id & how can in single booking id it can get this much of revenue
# Out:
# Minimum_Bookings:- 6500
# Maximum_Bookings:- 28560000
# Average_Bookings:- 15378.036937686695

# %%
#To handle this error we have to do 3 std deviation outlier
#It is 1 standard deviation
avg,std = df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
#Outlier => It is data point that is too extreme to remove outlier & we use techniques called standard deviation

# %%
avg,std
# Out:
# (15378.036937686695, 93040.15493143328)

# %%
#If any value is more than 3 standard deviation away from mean(which is an average) then we can filter it out
#To get 3 standard deviation
higher_limit = avg+ 3*std
higher_limit
# Out:
# 294498.50173198653

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# -263742.4278566132

# %%
#To check whether there is any negative revenue
df_bookings[df_bookings.revenue_generated<0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
#To check the higher limit
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
#To handle this error we can ignore it because it doesnot affect anything in eda as these values are few & to do this 
df_bookings = df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings
#after the cleaning store it to original data frame
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
#Explore the revenue realized
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
#So in revenue realized we have seen that maximum rent is 45220, so to check this value is valid or not we have perform again the 3 std deviation
higher_limit_1 = df_bookings.revenue_realized.mean() + 3*df_bookings.revenue_realized.std()
higher_limit_1
# Out:
# 33479.3586618449

# %%
#So we have got the higher limit & maximum value is differnet so we have the outlier but lets detail analysis
df_bookings[df_bookings.revenue_realized>higher_limit_1]
#So after observing there are 1299 outliers means huge but these all cost for room category RT4
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
#Lets see what is RT4
df_rooms = pd.read_csv("Datasets/dim_rooms.csv")
df_rooms
#So as we can see RT4 is presidential so the values are correct lets check further
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
#Instead doing mean & standard deviation on entire data frame i want to do all these only on RT4
df_bookings[df_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
#Here higher limit comes to be 50583 and in our dataframe above we can see that max value for revenue realized is 45220. 
#Hence we can conclude that there is no outlier and we don't need to do any data cleaning on this particular column
23439 + 3*9048
# Out:
# 50583

# %%
#Total values in our dataframe is 134576. Out of that 77899 rows has null rating. Since there are many rows with null rating, 
#we should not filter these values. Also we should not replace this rating with a median or mean rating etc 
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
#In aggregate bookings find columns that have null values. 
#Fill these null values with whatever you think is the appropriate subtitute (possible ways is to use mean or median)

#opened the fact_agg_bookings
df_agg_bookings = pd.read_csv("Datasets/fact_aggregated_bookings.csv")
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
#Check the null values
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
#Check the indivial column where null values if found
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
#Filling the null values using mean
df_agg_bookings.capacity.fillna(df_agg_bookings.capacity.mean())
# Out:
# 0       30.0
# 1       30.0
# 2       30.0
# 3       19.0
# 4       19.0
#         ...
# 9195    18.0
# 9196    18.0
# 9197     6.0
# 9198     6.0
# 9199     4.0
# Name: capacity, Length: 9200, dtype: float64

# %%
#Checking null are handled or not
df_agg_bookings.iloc[[8,15]]
# Out:
#     property_id check_in_date room_category  successful_bookings   capacity
# 8         17561      1-May-22           RT1                   22  25.280496
# 15        17563      1-May-22           RT1                   21  25.000000

# %%
#In aggregate bookings find out records that have successful_bookings value greater than capacity. Filter those records
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0
